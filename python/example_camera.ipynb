# %%
# %load_ext autoreload
# %autoreload 2

from camera import ThorlabsCamera

# %%
cam = ThorlabsCamera(serial_number='05564', name='Near field')
# Out:
# Available cameras: ['05564']

# %%
cam.setup(
    exposure_time_us=1000,
    roi_xy_size=(512,512),
    roi_xy_upper_left=(0,0),
    )

# %%
cam.run()

# %%
cam.exposure_us = 1000

# %%
cam.get_snapshot(display_timer=True)
cam.show(max=10000)
# Out:
# Acquisition time: 0.0 us

# %%
cam.live()
# Out:
# Generating app...
# Starting image acquisition thread...
# App starting
# Waiting for image acquisition thread to finish...
# Image acquisition has stopped

# %%
cam.dispose()
